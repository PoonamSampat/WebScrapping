# %%
import numpy as np
import pandas as pd

# %%
diab_maindf = pd.read_csv("diabetic_data.csv")

# %%
diabetes_df = diab_maindf

diabetes_df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...

# %%
diabetes_df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
diabetes_df.loc[0, :]
# Out:
# encounter_id                                 2278392
# patient_nbr                                  8222157
# race                                       Caucasian
# gender                                        Female
# age                                           [0-10)
# weight                                             ?
# admission_type_id                                  6
# discharge_disposition_id                          25
# admission_source_id                                1
# time_in_hospital                                   1
# payer_code                                         ?
# medical_specialty           Pediatrics-Endocrinology
# num_lab_procedures                                41
# num_procedures                                     0
# num_medications                                    1
# number_outpatient                                  0
# number_emergency                                   0
# number_inpatient                                   0
# ...

# %%
diabetes_df['insulin'] = diabetes_df['insulin'].map({'No': 'no-Insulin', 'Steady': 'insulin-Steady', 'Up':'insulin-Up', 'Down':'insulin-Down'})
diabetes_df['change'] = diabetes_df['change'].map({'No': 'change-No', 'Ch': 'change-Yes'})
diabetes_df['diabetesMed'] = diabetes_df['diabetesMed'].map({'No': 'diabetesMed-No', 'Yes': 'diabetesMed-Yes'})
diabetes_df['readmitted'] = diabetes_df['readmitted'].map({'NO': 'Not-readmitted', '>30': 'readmitted>30', '<30':'readmitted<30'})

# %%
diabetes_df['admission_type_id'] = diabetes_df['admission_type_id'].astype(str)
diabetes_df['admission_type_id'] = diabetes_df['admission_type_id'].map({'1': 'Emergency', '2': 'Urgent', '3':'Elective', '4':'Newborn', '5':'Desc Not Available','6':'NULL AD','7':'Trauma Center','8':'Not Mapped AD'})

# %%
diabetes_df['discharge_disposition_id'] = diabetes_df['discharge_disposition_id'].astype(str)
diabetes_df['discharge_disposition_id'] = diabetes_df['discharge_disposition_id'].map({'1': 'Discharged to home', '2': 'Discharged/transferred to another short term hospital', '3':'Discharged/transferred to SNF', '4':'Discharged/transferred to ICF', '5':'Discharged/transferred to another type of inpatient care institution','6':'Discharged/transferred to home with home health service','7':'Left AMA','8':'Discharged/transferred to home under care of Home IV provider','9':'Admitted as an inpatient to this hospital','10':'Neonate discharged to another hospital for neonatal aftercare','11':'Expired'})

# %%
diabetes_df['admission_source_id'] = diabetes_df['admission_source_id'].astype(str)
diabetes_df['admission_source_id'] = diabetes_df['admission_source_id'].map({'1': 'Physician Referral', '2': 'Clinic Referral', '3':'HMO Referral', '4':'Transfer from a hospital', '5':' Transfer from a Skilled Nursing Facility (SNF)','6':'Transfer from another health care facility','7':'Emergency Room','8':' Court/Law Enforcement','9':' Not Available','10':' Transfer from critial access hospital','11':'Normal Delivery','12':'Premature Delivery','13':' Sick Baby','14':' Extramural Birth','15':'Not Available','18':' Transfer From Another Home Health Agency','19':'Readmission to Same Home Health Agency','22':' Transfer from hospital inpt/same fac reslt in a sep claim','23':' Born inside this hospital','24':' Born outside this hospital','26':' Transfer from Ambulatory Surgery Center','26':'Transfer from Hospice'})

# %%
diabetes_df['number_emergency'] = diabetes_df['number_emergency'].astype(str)
diabetes_df['number_emergency'] =diabetes_df['number_emergency'] + 'Em'

# %%
del diabetes_df['patient_nbr']
del diabetes_df['medical_specialty']
del diabetes_df['payer_code']
del diabetes_df['encounter_id']

# %%
del diabetes_df['metformin']
del diabetes_df['repaglinide']
del diabetes_df['nateglinide']
del diabetes_df['chlorpropamide']
del diabetes_df['glimepiride']
del diabetes_df['glipizide']
del diabetes_df['glyburide']
del diabetes_df['tolbutamide']
del diabetes_df['rosiglitazone']
del diabetes_df['acarbose']
del diabetes_df['miglitol']
del diabetes_df['troglitazone']
del diabetes_df['examide']
del diabetes_df['glyburide-metformin']
del diabetes_df['glipizide-metformin']
del diabetes_df['glimepiride-pioglitazone']
del diabetes_df['metformin-rosiglitazone']
del diabetes_df['metformin-pioglitazone']
del diabetes_df['acetohexamide']
del diabetes_df['pioglitazone']
del diabetes_df['citoglipton']

# %%
del diabetes_df['weight']

# %%
basket= diabetes_df

# %%
basket.head(20)
# Out:
#                race  gender       age admission_type_id  \
# 0         Caucasian  Female    [0-10)           NULL AD
# 1         Caucasian  Female   [10-20)         Emergency
# 2   AfricanAmerican  Female   [20-30)         Emergency
# 3         Caucasian    Male   [30-40)         Emergency
# 4         Caucasian    Male   [40-50)         Emergency
# 5         Caucasian    Male   [50-60)            Urgent
# 6         Caucasian    Male   [60-70)          Elective
# 7         Caucasian    Male   [70-80)         Emergency
# 8         Caucasian  Female   [80-90)            Urgent
# 9         Caucasian  Female  [90-100)          Elective
# 10  AfricanAmerican  Female   [40-50)         Emergency
# 11  AfricanAmerican    Male   [60-70)            Urgent
# 12        Caucasian  Female   [40-50)         Emergency
# 13        Caucasian    Male   [80-90)         Emergency
# 14  AfricanAmerican  Female   [60-70)          Elective
# 15  AfricanAmerican    Male   [60-70)         Emergency
# ...

# %%
basket.to_csv("basket_diab.csv", encoding='utf-8', index=False)
